# %% [markdown]
# <a href="https://colab.research.google.com/github/shashankrawt-wq/customer-intelligence-pipeline/blob/main/01_setup_and_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Cell 2: Install additional packages
# !pip install sqlalchemy psycopg2-binary APScheduler xgboost pyyaml python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 38.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import requests
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import sqlalchemy
import yaml
import pytz

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 2.0.2

# %%
 # Cell 4: Create project folders in Google Drive
import os

# Define project path
project_path = '/content/drive/MyDrive/customer-intelligence-pipeline'

# Create folders
folders = [
    'data/raw',
    'data/processed',
    'data/powerbi',
    'models',
    'logs',
    'notebooks_backups'
]

for folder in folders:
    folder_path = os.path.join(project_path, folder)
    os.makedirs(folder_path, exist_ok=True)
    print(f" Created: {folder_path}")

print("\n All folders created in Google Drive!")
# Out:
#  Created: /content/drive/MyDrive/customer-intelligence-pipeline/data/raw
#  Created: /content/drive/MyDrive/customer-intelligence-pipeline/data/processed
#  Created: /content/drive/MyDrive/customer-intelligence-pipeline/data/powerbi
#  Created: /content/drive/MyDrive/customer-intelligence-pipeline/models
#  Created: /content/drive/MyDrive/customer-intelligence-pipeline/logs
#  Created: /content/drive/MyDrive/customer-intelligence-pipeline/notebooks_backups
#
#  All folders created in Google Drive!

# %% [markdown]
# # Google Colab Setup and Testing
#
# ## Overview
# This notebook sets up the Google Colab environment for the Customer Intelligence Analytics Platform project.
#
# ## What This Notebook Does:
# 1. Mounts Google Drive for file storage
# 2. Installs additional Python packages
# 3. Tests all imports to verify everything works
# 4. Creates project folder structure in Google Drive
#
# ## Setup Status
# ✅ Google Drive mounted
# ✅ All packages installed
# ✅ All imports tested
# ✅ Project folders created
